# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and load the dataset.
"""
fpath = keras.utils.get_file(
    "moving_mnist.npy",
    "http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy",
)
"""
fpath = "/content/drive/MyDrive/PBL_Shared_Data/202101_resizedby64.npy"
dataset = np.load(fpath)

# Swap the axes representing the number of frames and number of data samples.
dataset = np.swapaxes(dataset, 0, 1)
# We'll pick out 1000 of the 10000 total examples and use those.
dataset = dataset[:1000, ...]
# Add a channel dimension since the images are grayscale.
dataset = np.expand_dims(dataset, axis=-1)

# Split into train and validation sets using indexing to optimize memory.
indexes = np.arange(dataset.shape[0])
np.random.shuffle(indexes)
train_index = indexes[: int(0.9 * dataset.shape[0])]
val_index = indexes[int(0.9 * dataset.shape[0]) :]
train_dataset = dataset[train_index]
val_dataset = dataset[val_index]

# Normalize the data to the 0-1 range.
train_dataset = train_dataset / 255
val_dataset = val_dataset / 255

# We'll define a helper function to shift the frames, where
# `x` is frames 0 to n - 1, and `y` is frames 1 to n.
def create_shifted_frames(data):
    x = data[:, 0 : data.shape[1] - 1, :, :]
    y = data[:, 1 : data.shape[1], :, :]
    return x, y


# Apply the processing function to the datasets.
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)

# Inspect the dataset.
print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
# Out:
# Training Dataset Shapes: (27, 23, 64, 64, 1), (27, 23, 64, 64, 1)
# Validation Dataset Shapes: (3, 23, 64, 64, 1), (3, 23, 64, 64, 1)

# %%
# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(4, 6, figsize=(10, 8))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(train_dataset)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(train_dataset[data_choice][idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {data_choice}.")
plt.show()
# Out:
# Displaying frames for example 16.

# %%
np.__version__
# Out:
# '1.21.6'

# %%
# Construct the input layer with no definite frame size.
inp = layers.Input(shape=(None, *x_train.shape[2:]))
fs = 64
# We will construct 3 `ConvLSTM2D` layers with batch normalization,
# followed by a `Conv3D` layer for the spatiotemporal outputs.
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="relu",
)(inp)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.Conv3D(
    filters=1, kernel_size=(3, 3, 3), activation="sigmoid", padding="same"
)(x)

# Next, we will build the complete model and compile it.
model = keras.models.Model(inp, x)
model.compile(
    loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
)

# %%
# Define some callbacks to improve training.
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# Define modifiable training hyperparameters.
epochs = 200
batch_size = 5

# Fit the model to the training data.
model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_val, y_val),
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5823 - val_loss: 0.6667 - lr: 0.0010
# Epoch 2/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5820 - val_loss: 0.6662 - lr: 0.0010
# Epoch 3/200
# 6/6 [==============================] - 6s 961ms/step - loss: 0.5818 - val_loss: 0.6655 - lr: 0.0010
# Epoch 4/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.5816 - val_loss: 0.6651 - lr: 0.0010
# Epoch 5/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.5816 - val_loss: 0.6643 - lr: 0.0010
# Epoch 6/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.5813 - val_loss: 0.6639 - lr: 0.0010
# Epoch 7/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5811 - val_loss: 0.6634 - lr: 0.0010
# Epoch 8/200
# 6/6 [==============================] - 6s 963ms/step - loss: 0.5809 - val_loss: 0.6626 - lr: 0.0010
# Epoch 9/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5807 - val_loss: 0.6610 - lr: 0.0010
# Epoch 10/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5826 - val_loss: 0.6601 - lr: 0.0010
# Epoch 11/200
# 6/6 [==============================] - 6s 943ms/step - loss: 0.5822 - val_loss: 0.6598 - lr: 0.0010
# Epoch 12/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5812 - val_loss: 0.6593 - lr: 0.0010
# Epoch 13/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5808 - val_loss: 0.6582 - lr: 0.0010
# Epoch 14/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5804 - val_loss: 0.6576 - lr: 0.0010
# Epoch 15/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5802 - val_loss: 0.6567 - lr: 0.0010
# Epoch 16/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5800 - val_loss: 0.6560 - lr: 0.0010
# Epoch 17/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5798 - val_loss: 0.6551 - lr: 0.0010
# Epoch 18/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5796 - val_loss: 0.6544 - lr: 0.0010
# Epoch 19/200
# 6/6 [==============================] - 6s 962ms/step - loss: 0.5794 - val_loss: 0.6537 - lr: 0.0010
# Epoch 20/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5793 - val_loss: 0.6536 - lr: 0.0010
# Epoch 21/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5794 - val_loss: 0.6520 - lr: 0.0010
# Epoch 22/200
# 6/6 [==============================] - 6s 960ms/step - loss: 0.5790 - val_loss: 0.6515 - lr: 0.0010
# Epoch 23/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5787 - val_loss: 0.6509 - lr: 0.0010
# Epoch 24/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5784 - val_loss: 0.6495 - lr: 0.0010
# Epoch 25/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5782 - val_loss: 0.6485 - lr: 0.0010
# Epoch 26/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5780 - val_loss: 0.6470 - lr: 0.0010
# Epoch 27/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5778 - val_loss: 0.6460 - lr: 0.0010
# Epoch 28/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5776 - val_loss: 0.6448 - lr: 0.0010
# Epoch 29/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5774 - val_loss: 0.6436 - lr: 0.0010
# Epoch 30/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5773 - val_loss: 0.6424 - lr: 0.0010
# Epoch 31/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5772 - val_loss: 0.6413 - lr: 0.0010
# Epoch 32/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.5775 - val_loss: 0.6393 - lr: 0.0010
# Epoch 33/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.5771 - val_loss: 0.6387 - lr: 0.0010
# Epoch 34/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5769 - val_loss: 0.6377 - lr: 0.0010
# Epoch 35/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5768 - val_loss: 0.6365 - lr: 0.0010
# Epoch 36/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5767 - val_loss: 0.6353 - lr: 0.0010
# Epoch 37/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5766 - val_loss: 0.6341 - lr: 0.0010
# Epoch 38/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5765 - val_loss: 0.6328 - lr: 0.0010
# Epoch 39/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5764 - val_loss: 0.6315 - lr: 0.0010
# Epoch 40/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5764 - val_loss: 0.6298 - lr: 0.0010
# Epoch 41/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5771 - val_loss: 0.6301 - lr: 0.0010
# Epoch 42/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5766 - val_loss: 0.6292 - lr: 0.0010
# Epoch 43/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5764 - val_loss: 0.6291 - lr: 0.0010
# Epoch 44/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5762 - val_loss: 0.6275 - lr: 0.0010
# Epoch 45/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5761 - val_loss: 0.6261 - lr: 0.0010
# Epoch 46/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5760 - val_loss: 0.6245 - lr: 0.0010
# Epoch 47/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5760 - val_loss: 0.6234 - lr: 0.0010
# Epoch 48/200
# 6/6 [==============================] - 6s 958ms/step - loss: 0.5759 - val_loss: 0.6224 - lr: 0.0010
# Epoch 49/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.5759 - val_loss: 0.6212 - lr: 0.0010
# Epoch 50/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5759 - val_loss: 0.6200 - lr: 0.0010
# Epoch 51/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5758 - val_loss: 0.6189 - lr: 0.0010
# Epoch 52/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5758 - val_loss: 0.6176 - lr: 0.0010
# Epoch 53/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5758 - val_loss: 0.6163 - lr: 0.0010
# Epoch 54/200
# 6/6 [==============================] - 6s 964ms/step - loss: 0.5758 - val_loss: 0.6151 - lr: 0.0010
# Epoch 55/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5757 - val_loss: 0.6138 - lr: 0.0010
# Epoch 56/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5757 - val_loss: 0.6124 - lr: 0.0010
# Epoch 57/200
# 6/6 [==============================] - 6s 961ms/step - loss: 0.5759 - val_loss: 0.6109 - lr: 0.0010
# Epoch 58/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5758 - val_loss: 0.6096 - lr: 0.0010
# Epoch 59/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5757 - val_loss: 0.6087 - lr: 0.0010
# Epoch 60/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5757 - val_loss: 0.6077 - lr: 0.0010
# Epoch 61/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5757 - val_loss: 0.6067 - lr: 0.0010
# Epoch 62/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5756 - val_loss: 0.6054 - lr: 0.0010
# Epoch 63/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5756 - val_loss: 0.6041 - lr: 0.0010
# Epoch 64/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5756 - val_loss: 0.6030 - lr: 0.0010
# Epoch 65/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5756 - val_loss: 0.6020 - lr: 0.0010
# Epoch 66/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5757 - val_loss: 0.6005 - lr: 0.0010
# Epoch 67/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5757 - val_loss: 0.5996 - lr: 0.0010
# Epoch 68/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5756 - val_loss: 0.5986 - lr: 0.0010
# Epoch 69/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5756 - val_loss: 0.5976 - lr: 0.0010
# Epoch 70/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5756 - val_loss: 0.5967 - lr: 0.0010
# Epoch 71/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5755 - val_loss: 0.5958 - lr: 0.0010
# Epoch 72/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5755 - val_loss: 0.5949 - lr: 0.0010
# Epoch 73/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5755 - val_loss: 0.5940 - lr: 0.0010
# Epoch 74/200
# 6/6 [==============================] - 6s 940ms/step - loss: 0.5755 - val_loss: 0.5930 - lr: 0.0010
# Epoch 75/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5755 - val_loss: 0.5922 - lr: 0.0010
# Epoch 76/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5755 - val_loss: 0.5914 - lr: 0.0010
# Epoch 77/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5755 - val_loss: 0.5907 - lr: 0.0010
# Epoch 78/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5756 - val_loss: 0.5904 - lr: 0.0010
# Epoch 79/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5758 - val_loss: 0.5892 - lr: 0.0010
# Epoch 80/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5756 - val_loss: 0.5882 - lr: 0.0010
# Epoch 81/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5755 - val_loss: 0.5875 - lr: 0.0010
# Epoch 82/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5755 - val_loss: 0.5867 - lr: 0.0010
# Epoch 83/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5755 - val_loss: 0.5861 - lr: 0.0010
# Epoch 84/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5755 - val_loss: 0.5855 - lr: 0.0010
# Epoch 85/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5754 - val_loss: 0.5848 - lr: 0.0010
# Epoch 86/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5754 - val_loss: 0.5843 - lr: 0.0010
# Epoch 87/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5754 - val_loss: 0.5837 - lr: 0.0010
# Epoch 88/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5754 - val_loss: 0.5832 - lr: 0.0010
# Epoch 89/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5754 - val_loss: 0.5827 - lr: 0.0010
# Epoch 90/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5754 - val_loss: 0.5822 - lr: 0.0010
# Epoch 91/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5754 - val_loss: 0.5817 - lr: 0.0010
# Epoch 92/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5754 - val_loss: 0.5813 - lr: 0.0010
# Epoch 93/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5756 - val_loss: 0.5805 - lr: 0.0010
# Epoch 94/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5755 - val_loss: 0.5803 - lr: 0.0010
# Epoch 95/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5754 - val_loss: 0.5798 - lr: 0.0010
# Epoch 96/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5754 - val_loss: 0.5795 - lr: 0.0010
# Epoch 97/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5754 - val_loss: 0.5791 - lr: 0.0010
# Epoch 98/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5754 - val_loss: 0.5789 - lr: 0.0010
# Epoch 99/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5754 - val_loss: 0.5785 - lr: 0.0010
# Epoch 100/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5754 - val_loss: 0.5783 - lr: 0.0010
# Epoch 101/200
# 6/6 [==============================] - 6s 965ms/step - loss: 0.5754 - val_loss: 0.5780 - lr: 0.0010
# Epoch 102/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5754 - val_loss: 0.5779 - lr: 0.0010
# Epoch 103/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5754 - val_loss: 0.5777 - lr: 0.0010
# Epoch 104/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5754 - val_loss: 0.5775 - lr: 0.0010
# Epoch 105/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5754 - val_loss: 0.5772 - lr: 0.0010
# Epoch 106/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5754 - val_loss: 0.5772 - lr: 0.0010
# Epoch 107/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5754 - val_loss: 0.5769 - lr: 0.0010
# Epoch 108/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5754 - val_loss: 0.5767 - lr: 0.0010
# Epoch 109/200
# 6/6 [==============================] - 6s 960ms/step - loss: 0.5753 - val_loss: 0.5765 - lr: 0.0010
# Epoch 110/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5753 - val_loss: 0.5765 - lr: 0.0010
# Epoch 111/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5763 - lr: 0.0010
# Epoch 112/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5753 - val_loss: 0.5762 - lr: 0.0010
# Epoch 113/200
# 6/6 [==============================] - 6s 944ms/step - loss: 0.5753 - val_loss: 0.5761 - lr: 0.0010
# Epoch 114/200
# 6/6 [==============================] - 6s 958ms/step - loss: 0.5754 - val_loss: 0.5761 - lr: 0.0010
# Epoch 115/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5760 - lr: 0.0010
# Epoch 116/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5754 - val_loss: 0.5761 - lr: 0.0010
# Epoch 117/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.5754 - val_loss: 0.5760 - lr: 0.0010
# Epoch 118/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5754 - val_loss: 0.5757 - lr: 0.0010
# Epoch 119/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5753 - val_loss: 0.5757 - lr: 0.0010
# Epoch 120/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5753 - val_loss: 0.5757 - lr: 0.0010
# Epoch 121/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5756 - lr: 0.0010
# Epoch 122/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5753 - val_loss: 0.5756 - lr: 0.0010
# Epoch 123/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5755 - lr: 0.0010
# Epoch 124/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5755 - lr: 0.0010
# Epoch 125/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5755 - lr: 0.0010
# Epoch 126/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5755 - lr: 0.0010
# Epoch 127/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5757 - lr: 0.0010
# Epoch 128/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.5755 - val_loss: 0.5755 - lr: 0.0010
# Epoch 129/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5754 - val_loss: 0.5755 - lr: 0.0010
# Epoch 130/200
# 6/6 [==============================] - 6s 958ms/step - loss: 0.5753 - val_loss: 0.5754 - lr: 1.0000e-04
# Epoch 131/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5753 - val_loss: 0.5754 - lr: 1.0000e-04
# Epoch 132/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5754 - lr: 1.0000e-04
# Epoch 133/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5754 - lr: 1.0000e-04
# Epoch 134/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-04
# Epoch 135/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-04
# Epoch 136/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-04
# Epoch 137/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-04
# Epoch 138/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-04
# Epoch 139/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-05
# Epoch 140/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-05
# Epoch 141/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-05
# Epoch 142/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-05
# Epoch 143/200
# 6/6 [==============================] - 6s 958ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-05
# Epoch 144/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-06
# Epoch 145/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-06
# Epoch 146/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-06
# Epoch 147/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-06
# Epoch 148/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-06
# Epoch 149/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-07
# Epoch 150/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-07
# Epoch 151/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-07
# Epoch 152/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-07
# Epoch 153/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-07
# Epoch 154/200
# 6/6 [==============================] - 6s 947ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-08
# Epoch 155/200
# 6/6 [==============================] - 6s 942ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-08
# Epoch 156/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-08
# Epoch 157/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-08
# Epoch 158/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-08
# Epoch 159/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-09
# Epoch 160/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-09
# Epoch 161/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-09
# Epoch 162/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-09
# Epoch 163/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-09
# Epoch 164/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-10
# Epoch 165/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-10
# Epoch 166/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-10
# Epoch 167/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-10
# Epoch 168/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-10
# Epoch 169/200
# 6/6 [==============================] - 6s 955ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-11
# Epoch 170/200
# 6/6 [==============================] - 6s 950ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-11
# Epoch 171/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-11
# Epoch 172/200
# 6/6 [==============================] - 6s 944ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-11
# Epoch 173/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-11
# Epoch 174/200
# 6/6 [==============================] - 6s 964ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-12
# Epoch 175/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-12
# Epoch 176/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-12
# Epoch 177/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-12
# Epoch 178/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-12
# Epoch 179/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-13
# Epoch 180/200
# 6/6 [==============================] - 6s 948ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-13
# Epoch 181/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-13
# Epoch 182/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-13
# Epoch 183/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-13
# Epoch 184/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-14
# Epoch 185/200
# 6/6 [==============================] - 6s 957ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-14
# Epoch 186/200
# 6/6 [==============================] - 6s 1s/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-14
# Epoch 187/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-14
# Epoch 188/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-14
# Epoch 189/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-15
# Epoch 190/200
# 6/6 [==============================] - 6s 956ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-15
# Epoch 191/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-15
# Epoch 192/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-15
# Epoch 193/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-15
# Epoch 194/200
# 6/6 [==============================] - 6s 959ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-16
# Epoch 195/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-16
# Epoch 196/200
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-16
# Epoch 197/200
# 6/6 [==============================] - 6s 949ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-16
# Epoch 198/200
# 6/6 [==============================] - 6s 944ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-16
# Epoch 199/200
# 6/6 [==============================] - 6s 953ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-17
# Epoch 200/200
# 6/6 [==============================] - 6s 946ms/step - loss: 0.5753 - val_loss: 0.5753 - lr: 1.0000e-17

# %%
# Select a random example from the validation dataset.
example = val_dataset[np.random.choice(range(len(val_dataset)), size=1)[0]]

# Pick the first/last ten frames from the example.
frames = example[:10, ...]
original_frames = example[10:, ...]

# Predict a new set of 10 frames.
for _ in range(10):
    # Extract the model's prediction and post-process it.
    new_prediction = model.predict(np.expand_dims(frames, axis=0))
    new_prediction = np.squeeze(new_prediction, axis=0)
    predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

    # Extend the set of prediction frames.
    frames = np.concatenate((frames, predicted_frame), axis=0)

# Construct a figure for the original and new frames.
fig, axes = plt.subplots(2, 10, figsize=(20, 4))

# Plot the original frames.
for idx, ax in enumerate(axes[0]):
    ax.imshow(np.squeeze(original_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Plot the new frames.
new_frames = frames[10:, ...]
for idx, ax in enumerate(axes[1]):
    ax.imshow(np.squeeze(new_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Display the figure.
plt.show()

# %%
# Select a few random examples from the dataset.
examples = val_dataset[np.random.choice(range(len(val_dataset)), size=5)]

# Iterate over the examples and predict the frames.
predicted_videos = []
for example in examples:
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the model's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = model.predict(np.expand_dims(frames, axis=0))
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame

    # Create and save GIFs for each of the ground truth/prediction images.
    for frame_set in [original_frames, new_predictions]:
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        # Construct a GIF from the frames.
        with io.BytesIO() as gif:
            imageio.mimsave(gif, current_frames, "GIF", fps=5)
            predicted_videos.append(gif.getvalue())

# Display the videos.
print(" Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    # Construct and display an `HBox` with the ground truth and prediction.
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i]),
            widgets.Image(value=predicted_videos[i + 1]),
        ]
    )
    display(box)
# Out:
#  Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xf4\xf4\xf4\xef\xef\xef\xee\xee\xee\xec\xec\xec\xeb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xf4\xf4\xf4\xef\xef\xef\xee\xee\xee\xec\xec\xec\xeb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xf4\xf4\xf4\xef\xef\xef\xee\xee\xee\xec\xec\xec\xeb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xf4\xf4\xf4\xef\xef\xef\xee\xee\xee\xec\xec\xec\xeb\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xf4\xf4\xf4\xef\xef\xef\xee\xee\xee\xec\xec\xec\xeb\…
